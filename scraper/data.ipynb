# %%
import boto3
import json
import requests
from decimal import Decimal

# %%
table_name = 'newsmap-data'
primary_column = 'data_id'
sort_column = 'date'

# %%
data = json.loads(requests.get('https://api.npoint.io/d45deb15252bacd419f4').content, parse_float=Decimal)

# %%
client = boto3.resource('dynamodb',
    aws_access_key_id="AKIAWE4O5IJ6JDTGNMM5",
    aws_secret_access_key="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",
    region_name="ap-south-1")

table = client.Table(table_name)

# %%
response = table.put_item(Item = {
    primary_column : 0,
    sort_column : '13-11-2022',
    'tile_x' : 0,
    'tile_y' : 0,
    'data' : data
})

# %%
response
# Out:
# {'ResponseMetadata': {'RequestId': '6U0KNFSOC2A0C3J1MDNG5G432FVV4KQNSO5AEMVJF66Q9ASUAAJG',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'server': 'Server',
#    'date': 'Sun, 13 Nov 2022 11:39:16 GMT',
#    'content-type': 'application/x-amz-json-1.0',
#    'content-length': '2',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': '6U0KNFSOC2A0C3J1MDNG5G432FVV4KQNSO5AEMVJF66Q9ASUAAJG',
#    'x-amz-crc32': '2745614147'},
#   'RetryAttempts': 0}}

# %%
from boto3.dynamodb.conditions import Key, Attr
response = table.scan(
    FilterExpression = Attr('data_id').gte(0)
)

# %%
response = table.delete_item(
    Key = {
        'data_id': 1,
        'date':'13-11-2022'
    }
)

# %%
response = table.get_item(
    Key = {
        'data_id':0,
        'date':'13-11-2022'
    }
)

# %%
response['Item']['data']
# Out:
# [{'name': 'Hindustan Times',
#   'count': Decimal('364'),
#   'image': 'https://www.hindustantimes.com/res/images/logo.png',
#   'source_tag': 'ht',
#   'data': {'Lucknow': {'count': Decimal('20'),
#     'cordinates': [Decimal('80.9346001'), Decimal('26.8381')],
#     'links': [{'title': 'Dimple Yadav to file nomination for Mainpuri Lok Sabha bypolls on Monday',
#       'img': 'https://images.hindustantimes.com/img/2022/11/13/550x309/d3749a52-612a-11ed-a886-4f0eae2e705f_1668332394230_1668332394230_1668332447528_1668332447528.jpg',
#       'url': 'https://www.hindustantimes.com/cities/lucknow-news/dimple-yadav-to-file-nomination-for-mainpuri-lok-sabha-bypolls-on-monday-101668331794734.html'},
#      {'title': 'Police bust fake dealership racket in Patna; 16 held',
#       'img': 'https://images.hindustantimes.com/img/2022/11/13/550x309/8b81292c-6323-11ed-bcc6-92f852aad067_1668324492777.jpg',
# ...

# %%
table
# Out:
# dynamodb.Table(name='newsmap-data')
